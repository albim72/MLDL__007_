# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import kmeans_plusplus

# %%
n_samples = 15000
n_components = 5

# %%
X,y_true = make_blobs(n_samples=n_samples,centers=n_components,cluster_std=1.25,random_state=1)
X = X[:,::-1]

# %%
centers_init,indices = kmeans_plusplus(X,n_clusters=5,random_state=0)

# %%
plt.figure()
colors = ["#4EACC5","#FF9C34", "#4E9A06","m","c"]  # Add '#' before '4E9A06'
for k,col in enumerate(colors):
    cluster_data = y_true == k
    plt.scatter(X[cluster_data,0],X[cluster_data,1],c=col,marker=".",s=10)

plt.scatter(centers_init[:,0],centers_init[:,1],c="b",s=50)
plt.title("algorytm k-means")
plt.xticks([])
plt.yticks([])
plt.show()
